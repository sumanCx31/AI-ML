# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('student_portuguese_clean.csv')

# %%
df
# Out:
#      student_id school sex  age address_type              family_size  \
# 0             1     GP   F   18        Urban           Greater than 3
# 1             2     GP   F   17        Urban           Greater than 3
# 2             3     GP   F   15        Urban  Less than or equal to 3
# 3             4     GP   F   15        Urban           Greater than 3
# 4             5     GP   F   16        Urban           Greater than 3
# ..          ...    ...  ..  ...          ...                      ...
# 644         645     MS   F   19        Rural           Greater than 3
# 645         646     MS   F   18        Urban  Less than or equal to 3
# 646         647     MS   F   18        Urban           Greater than 3
# 647         648     MS   M   17        Urban  Less than or equal to 3
# 648         649     MS   M   18        Rural  Less than or equal to 3
#
#        parent_status               mother_education  \
# 0              Apart               higher education
# ...

# %%
df['sex']
# Out:
# 0      F
# 1      F
# 2      F
# 3      F
# 4      F
#       ..
# 644    F
# 645    F
# 646    F
# 647    M
# 648    M
# Name: sex, Length: 649, dtype: object

# %%
df['sex'] = df['sex'].map({"F":0,"M":1})

# %%
df['sex']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 644    0
# 645    0
# 646    0
# 647    1
# 648    1
# Name: sex, Length: 649, dtype: int64

# %%
df.rename(columns={df.columns[2]: "isFemale"}, inplace=True)

# %%
df['parent_status'].value_counts()
# Out:
# parent_status
# Living together    569
# Apart               80
# Name: count, dtype: int64

# %%
columns = ["school","isFemale","age","family_size"]

# %%
# columns = ["school","sex","age","family_size"]
df[columns]
# Out:
#     school  isFemale  age              family_size
# 0       GP         0   18           Greater than 3
# 1       GP         0   17           Greater than 3
# 2       GP         0   15  Less than or equal to 3
# 3       GP         0   15           Greater than 3
# 4       GP         0   16           Greater than 3
# ..     ...       ...  ...                      ...
# 644     MS         0   19           Greater than 3
# 645     MS         0   18  Less than or equal to 3
# 646     MS         0   18           Greater than 3
# 647     MS         1   17  Less than or equal to 3
# 648     MS         1   18  Less than or equal to 3
#
# [649 rows x 4 columns]

# %%
df['family_size'].value_counts()
# Out:
# family_size
# Greater than 3             457
# Less than or equal to 3    192
# Name: count, dtype: int64
