# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset/foodmandu_data.csv")

# %%
df['Description/Ingredients']=df['Description/Ingredients'].isnull().fillna("")

# %%
df['Price']=df['Price'].str.replace(",","").astype(float)

# %%
df['Location']
# Out:
# 0        Putalisadak , New Plaza
# 1        Putalisadak , New Plaza
# 2        Putalisadak , New Plaza
# 3        Putalisadak , New Plaza
# 4        Putalisadak , New Plaza
#                   ...
# 78401                  Khumaltar
# 78402                  Khumaltar
# 78403                  Khumaltar
# 78404                  Khumaltar
# 78405                  Khumaltar
# Name: Location, Length: 78406, dtype: object

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df.Unnamed, df['Price'], color='blue', s=2)

plt.title('Scatter Plot of Study hoours vs Math marks')
plt.xlabel('Study hours per week')
plt.ylabel('Marks in math')
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16580\699360463.py in ?()
#       1 plt.figure(figsize=(10, 5))
# ----> 2 plt.scatter(df.Unnamed, df['Price'], color='blue', s=2)
#       3
#       4 plt.title('Scatter Plot of Study hoours vs Math marks')
#       5 plt.xlabel('Study hours per week')
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Unnamed'

# %%
df.shape
# Out:
# (78406, 8)

# %%
df['Price'] = df['Price'].replace(',', '')

# %%
# df['Price'] = df['Price'].astype(float)

# %%
df.info()

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#         Unnamed: 0
# count  78406.00000
# mean   39202.50000
# std    22634.00694
# min        0.00000
# 25%    19601.25000
# 50%    39202.50000
# 75%    58803.75000
# max    78405.00000

# %%
df[['Restaurant Name','Location']].head()
# Out:
#   Restaurant Name                 Location
# 0   The Mari Cafe  Putalisadak , New Plaza
# 1   The Mari Cafe  Putalisadak , New Plaza
# 2   The Mari Cafe  Putalisadak , New Plaza
# 3   The Mari Cafe  Putalisadak , New Plaza
# 4   The Mari Cafe  Putalisadak , New Plaza

# %%
df.iloc[4,3]
# Out:
# 'Putalisadak , New Plaza'

# %%
df.loc[4,"Location"]

# %%
df['Price']=df['Price'].str.replace(",","").astype(float)

# %%
df['Price']
# Out:
# 0        1190.0
# 1         910.0
# 2         450.0
# 3        1050.0
# 4         700.0
#           ...
# 78401     394.0
# 78402     289.0
# 78403     229.0
# 78404     249.0
# 78405     424.0
# Name: Price, Length: 78406, dtype: float64

# %%
df[df['Price'] < 500]
# Out:
#        Unnamed: 0                   Restaurant Name   Cuisine Type  \
# 2               2                     The Mari Cafe  Multi Cuisine
# 5               5                     The Mari Cafe  Multi Cuisine
# 8               8                     The Mari Cafe  Multi Cuisine
# 10             10                     The Mari Cafe  Multi Cuisine
# 13             13                     The Mari Cafe  Multi Cuisine
# ...           ...                               ...            ...
# 78401       78401  Dharane Sekuwa Corner - Lalitpur  Multi Cuisine
# 78402       78402  Dharane Sekuwa Corner - Lalitpur  Multi Cuisine
# 78403       78403  Dharane Sekuwa Corner - Lalitpur  Multi Cuisine
# 78404       78404  Dharane Sekuwa Corner - Lalitpur  Multi Cuisine
# 78405       78405  Dharane Sekuwa Corner - Lalitpur  Multi Cuisine
#
#                       Location  \
# 2      Putalisadak , New Plaza
# 5      Putalisadak , New Plaza
# 8      Putalisadak , New Plaza
# ...
